# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.array([1,2,3])
b=np.array([6,7,8,9])

# %%
a,b=np.meshgrid(a,b)

# %%
print(a)
print(b)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]
#  [1 2 3]]
# [[6 6 6]
#  [7 7 7]
#  [8 8 8]
#  [9 9 9]]

# %%
plt.style.use("seaborn")

# %%
fig=plt.figure()
axes=fig.gca(projection='3d')
axes.plot_surface(a,b,a+b,cmap="coolwarm")
plt.show()

# %%
# parabola Shaped Surface Plots
a=np.arange(-1,1,0.01)
b=a
a,b=np.meshgrid(a,b)

# %%
fig=plt.figure()
axes=fig.gca(projection='3d')
axes.plot_surface(a,b,a**2+b**2,cmap="rainbow")
plt.title("Surface Plots")
plt.show()

# %%
# Contour Plots

fig=plt.figure()
axes=fig.gca(projection='3d')
axes.contour(a,b,a**2+b**2,cmap="rainbow")
plt.title("Contour Plots")
plt.show()

# %%
# Save it as File -> Download as Python.py and rum from command line
#python "filename".py
